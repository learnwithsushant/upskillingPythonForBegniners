# %% [markdown]
# # Practicing Numpy

# %%
import numpy as np
import pandas as pd

# %%
l = [1,2,3,4,5]
a= np.array(l)
print(a)
# Out:
# [1 2 3 4 5]

# %%
print(a+10)
# Out:
# [11 12 13 14 15]

# %%
a.ndim
# Out:
# 1

# %%
a.shape
# Out:
# (5,)

# %%
a.tolist()
# Out:
# [1, 2, 3, 4, 5]

# %%
a[0]=2
print(a)
a[0]=15
# Out:
# [ 2 19 24 32 37 42 46]

# %%
l=[15,19,24,32,37,42,46]

a=np.array(l)

print(a)
# Out:
# [15 19 24 32 37 42 46]

# %%
a[2]
# Out:
# np.int64(24)

# %%
print(a[-2])
# Out:
# 42

# %%
a[1:6:1]
# Out:
# array([19, 24, 32, 37, 42])

# %%
a[:3]
# Out:
# array([15, 19, 24])

# %%
a[[0,2,4,5]]
# Out:
# array([15, 24, 37, 42])

# %%
a[a>40]
# Out:
# array([42, 46])

# %%
a%2==0
# Out:
# array([False, False,  True,  True, False,  True,  True])

# %%
a[a%2==0]
# Out:
# array([24, 32, 42, 46])

# %%
a[(a>30) & (a<40)]
# Out:
# array([32, 37])

# %%
(a>30) & (a<40)
# Out:
# array([False, False, False,  True,  True, False, False])

# %% [markdown]
# # Data Manipulation or Data Modification
# - Insert | Update | Delete

# %%
print(a)
# Out:
# [15 19 24 32 37 42 46]

# %%
np.append(a,50)
# Out:
# array([15, 19, 24, 32, 37, 42, 46, 50])

# %%
a1 = np.append(a,60)
print(a1)
# Out:
# [15 19 24 32 37 42 46 60]

# %%
a2 = np.append(a,[70,80])
print(a2)
# Out:
# [15 19 24 32 37 42 46 70 80]

# %% [markdown]
# # Delete Operation

# %%
a3 = np.delete(a,1)
print(a3)
# Out:
# [15 24 32 37 42 46]

# %%
a4 = np.delete(a,[1,3])
print(a4)
# Out:
# [15 24 37 42 46]

# %%
b = np.array([23,44,55,76])
print(b)
# Out:
# [23 44 55 76]

# %%
b[-1]=77
print(b)
# Out:
# [23 44 55 77]

# %%
b[[0,-2]]=51
print(b)
# Out:
# [51 44 51 77]

# %%
b[[0,-2]]=51,69
print(b)
# Out:
# [51 44 69 77]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 3
#       1 b[[0,-2]]=51,69
#       2 print(b)
# ----> 3 b.append(99)
#       4 print(b)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
c=np.sort(b)
print(c)
# Out:
# [44 51 69 77]

# %%
d=b.copy()
print(id(b))
print(id(d))
print(d)
# Out:
# 2217960155120
# 2217975385808
# [51 44 69 77]

# %%
print(d**2)
# Out:
# [2601 1936 4761 5929]

# %%
print(b+d)
# Out:
# [102  88 138 154]

# %%
print(d-b)
# Out:
# [0 0 0 0]

# %% [markdown]
# # Practicing Pandas

# %%
mixList=[12,True,23.56,'ssw']
mixedArray1=np.array(mixList)
print(mixedArray1)
print(mixedArray1.shape)
print(mixedArray1.ndim)
# Out:
# ['12' 'True' '23.56' 'ssw']
# (4,)
# 1

# %%
print(l)
# Out:
# [15, 19, 24, 32, 37, 42, 46]

# %%
s = pd.Series(l)
print(s)
# Out:
# 0    15
# 1    19
# 2    24
# 3    32
# 4    37
# 5    42
# 6    46
# dtype: int64

# %%
s.ndim
# Out:
# 1

# %%
s.shape
# Out:
# (7,)

# %%
np.random.randint(1,100,8)
# Out:
# array([15,  5, 68, 21, 34, 90, 70, 11], dtype=int32)
