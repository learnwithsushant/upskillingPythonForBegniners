# %% [markdown]
# # Practicing Pandas

# %%
import pandas as pd
import numpy as np

# %%
initialList = [15, 19, 24, 32, 37, 42, 46]
print(initialList)
# Out:
# [15, 19, 24, 32, 37, 42, 46]

# %%
numSeries = pd.Series(initialList)
print(numSeries+50)
# Out:
# 0    65
# 1    69
# 2    74
# 3    82
# 4    87
# 5    92
# 6    96
# dtype: int64

# %%
mixList=[12,True,23.56,'ssw']
mixSeries = pd.Series(mixList,index=['a','b','c','d'])
print(mixSeries)
# Out:
# a       12
# b     True
# c    23.56
# d      ssw
# dtype: object

# %%
mixSeries.ndim
# Out:
# 1

# %%
mixSeries.shape
# Out:
# (4,)

# %%
mixSeries.tolist()
# Out:
# [12, True, 23.56, 'ssw']

# %% [markdown]
# # Coverting dictionary to Series

# %%
d = {"a":20,"b":30,"c":40,"d":50,"e":60,"f":70,"g":80,"i":90}

dSeries = pd.Series(d)
print(dSeries)
# Out:
# a    20
# b    30
# c    40
# d    50
# e    60
# f    70
# g    80
# i    90
# dtype: int64

# %%
pd.Series(np.arange(5,51,5))
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# 5    30
# 6    35
# 7    40
# 8    45
# 9    50
# dtype: int64

# %%
pd.Series(np.random.randint(1,100,17))
# Out:
# 0      5
# 1     49
# 2     67
# 3     23
# 4     10
# 5     86
# 6     28
# 7     35
# 8     19
# 9     12
# 10    25
# 11    51
# 12    50
# 13    30
# 14    68
# 15    42
# 16    76
# dtype: int32
